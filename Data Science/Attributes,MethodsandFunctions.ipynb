# %%
import pandas as pd

# %%
df_data=pd.read_csv('SampleDocuments\\StudentDetails.csv')

# %%
df_data
# Out:
#      StudentID  Score        Date Description Ethnicity    Subject     Hobby  \
# 0            1     46  02:11:2025       Assam    Rajput    Zoology   Reading
# 1            2     50  28:10:2025    Bangluru      Odia  Chemistry  Shooting
# 2            3     80  08:11:2025      Gujrat   Maratha    Physics   Talking
# 3            4     85  28:10:2025       Noida   Kayasth     French  Shooting
# 4            5     73  01:11:2025       Delhi   Kayasth  Economics   Talking
# ..         ...    ...         ...         ...       ...        ...       ...
# 995        996     56  03:11:2025       Assam      Odia      Maths    Biking
# 996        997     85  06:11:2025    Shillong   Adiwasi  Economics   Cycling
# 997        998     69  12:11:2025       Delhi   Adiwasi      Hindi   Talking
# 998        999     42  02:11:2025     Varansi      Sikh    Physics  Teaching
# 999       1000     74  26:10:2025       Assam    Rajput  Chemistry   Talking
#
#        Interest  Age Grade
# ...

# %% [markdown]
# # 1. Attributes

# %%
# getting access to the shape attributes
df_data.shape
# Out:
# (1000, 10)

# %%
#index attribute
df_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#column attributes
df_data.columns
# Out:
# Index(['StudentID', 'Score', 'Date', 'Description', 'Ethnicity', 'Subject',
#        'Hobby', 'Interest', 'Age', 'Grade'],
#       dtype='object')

# %%
df_data
# Out:
#      StudentID  Score        Date Description Ethnicity    Subject     Hobby  \
# 0            1     46  02:11:2025       Assam    Rajput    Zoology   Reading
# 1            2     50  28:10:2025    Bangluru      Odia  Chemistry  Shooting
# 2            3     80  08:11:2025      Gujrat   Maratha    Physics   Talking
# 3            4     85  28:10:2025       Noida   Kayasth     French  Shooting
# 4            5     73  01:11:2025       Delhi   Kayasth  Economics   Talking
# ..         ...    ...         ...         ...       ...        ...       ...
# 995        996     56  03:11:2025       Assam      Odia      Maths    Biking
# 996        997     85  06:11:2025    Shillong   Adiwasi  Economics   Cycling
# 997        998     69  12:11:2025       Delhi   Adiwasi      Hindi   Talking
# 998        999     42  02:11:2025     Varansi      Sikh    Physics  Teaching
# 999       1000     74  26:10:2025       Assam    Rajput  Chemistry   Talking
#
#        Interest  Age Grade
# ...

# %%
# datatypes of each column
df_data.dtypes
# Out:
# StudentID       int64
# Score           int64
# Date           object
# Description    object
# Ethnicity      object
# Subject        object
# Hobby          object
# Interest       object
# Age             int64
# Grade          object
# dtype: object

# %% [markdown]
# # 2. Methods

# %%
#head
df_data.head()
# Out:
#    StudentID  Score        Date Description Ethnicity    Subject     Hobby  \
# 0          1     46  02:11:2025       Assam    Rajput    Zoology   Reading
# 1          2     50  28:10:2025    Bangluru      Odia  Chemistry  Shooting
# 2          3     80  08:11:2025      Gujrat   Maratha    Physics   Talking
# 3          4     85  28:10:2025       Noida   Kayasth     French  Shooting
# 4          5     73  01:11:2025       Delhi   Kayasth  Economics   Talking
#
#      Interest  Age Grade
# 0     Esports   19     D
# 1    Painting   17     F
# 2      Comedy   19     D
# 3    Painting   17     B
# 4  MotoRacing   16     D

# %%
# show info of dataframes
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StudentID    1000 non-null   int64
#  1   Score        1000 non-null   int64
#  2   Date         1000 non-null   object
#  3   Description  1000 non-null   object
#  4   Ethnicity    1000 non-null   object
#  5   Subject      1000 non-null   object
#  6   Hobby        1000 non-null   object
#  7   Interest     1000 non-null   object
#  8   Age          1000 non-null   int64
#  9   Grade        1000 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 78.3+ KB

# %%
# describe basic statistics
df_data.describe()
# Out:
#          StudentID        Score          Age
# count  1000.000000  1000.000000  1000.000000
# mean    500.500000    63.459000    17.525000
# std     288.819436    20.262697     1.123671
# min       1.000000    30.000000    16.000000
# 25%     250.750000    46.000000    17.000000
# 50%     500.500000    63.000000    18.000000
# 75%     750.250000    81.000000    19.000000
# max    1000.000000   100.000000    19.000000

# %% [markdown]
# # 3. Functions

# %%
#obtaining no. of rows of dataframes
len(df_data)
# Out:
# 1000

# %%
# Obtaining the highest index
max(df_data.index)
# Out:
# 999

# %%
min(df_data.index)
# Out:
# 0

# %%
# Obtaing dataframes
type(df_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# rounding the values of the dataset
round(df_data,2)
# Out:
#      StudentID  Score        Date Description Ethnicity    Subject     Hobby  \
# 0            1     46  02:11:2025       Assam    Rajput    Zoology   Reading
# 1            2     50  28:10:2025    Bangluru      Odia  Chemistry  Shooting
# 2            3     80  08:11:2025      Gujrat   Maratha    Physics   Talking
# 3            4     85  28:10:2025       Noida   Kayasth     French  Shooting
# 4            5     73  01:11:2025       Delhi   Kayasth  Economics   Talking
# ..         ...    ...         ...         ...       ...        ...       ...
# 995        996     56  03:11:2025       Assam      Odia      Maths    Biking
# 996        997     85  06:11:2025    Shillong   Adiwasi  Economics   Cycling
# 997        998     69  12:11:2025       Delhi   Adiwasi      Hindi   Talking
# 998        999     42  02:11:2025     Varansi      Sikh    Physics  Teaching
# 999       1000     74  26:10:2025       Assam    Rajput  Chemistry   Talking
#
#        Interest  Age Grade
# ...

# %% [markdown]
# # Value_counts() method

# %% [markdown]
# ### 1. Value Counts

# %%
# counting scores iwth. count
df_data['Score'].count()
# Out:
# np.int64(1000)

# %%
# counting no. of different scores
df_data['Ethnicity'].value_counts()
# Out:
# Ethnicity
# Sikh        157
# Kashmiri    134
# Adiwasi     129
# Maratha     126
# Rajput      122
# Odia        118
# Kayasth     110
# Bhramin     104
# Name: count, dtype: int64

# %%
df_data['Subject'].value_counts(normalize=True)
# Out:
# Subject
# Python            0.125
# Maths             0.115
# Chemistry         0.113
# Economics         0.110
# English           0.102
# Physics           0.099
# Zoology           0.096
# Hindi             0.085
# French            0.083
# Social Science    0.072
# Name: proportion, dtype: float64

# %% [markdown]
# # Set_index()

# %%
df_data.set_index('StudentID',inplace=True)

# %%
df_data.sort_index()
# Out:
#            Score        Date Description Ethnicity    Subject     Hobby  \
# StudentID
# 1             46  02:11:2025       Assam    Rajput    Zoology   Reading
# 2             50  28:10:2025    Bangluru      Odia  Chemistry  Shooting
# 3             80  08:11:2025      Gujrat   Maratha    Physics   Talking
# 4             85  28:10:2025       Noida   Kayasth     French  Shooting
# 5             73  01:11:2025       Delhi   Kayasth  Economics   Talking
# ...          ...         ...         ...       ...        ...       ...
# 996           56  03:11:2025       Assam      Odia      Maths    Biking
# 997           85  06:11:2025    Shillong   Adiwasi  Economics   Cycling
# 998           69  12:11:2025       Delhi   Adiwasi      Hindi   Talking
# 999           42  02:11:2025     Varansi      Sikh    Physics  Teaching
# 1000          74  26:10:2025       Assam    Rajput  Chemistry   Talking
#
#              Interest  Age Grade
# StudentID
# 1             Esports   19     D
# ...

# %% [markdown]
# # rename()

# %%
# rename column
df_data.rename(columns={'Score':'Marks'},inplace=True)
df_data
# Out:
#            Marks        Date Description Ethnicity    Subject     Hobby  \
# StudentID
# 1             46  02:11:2025       Assam    Rajput    Zoology   Reading
# 2             50  28:10:2025    Bangluru      Odia  Chemistry  Shooting
# 3             80  08:11:2025      Gujrat   Maratha    Physics   Talking
# 4             85  28:10:2025       Noida   Kayasth     French  Shooting
# 5             73  01:11:2025       Delhi   Kayasth  Economics   Talking
# ...          ...         ...         ...       ...        ...       ...
# 996           56  03:11:2025       Assam      Odia      Maths    Biking
# 997           85  06:11:2025    Shillong   Adiwasi  Economics   Cycling
# 998           69  12:11:2025       Delhi   Adiwasi      Hindi   Talking
# 999           42  02:11:2025     Varansi      Sikh    Physics  Teaching
# 1000          74  26:10:2025       Assam    Rajput  Chemistry   Talking
#
#              Interest  Age Grade
# StudentID
# 1             Esports   19     D
# ...
